# %%
import math
from textblob import TextBlob

# %%
docx1 = TextBlob("""NASA to explore how 3-year Mars mission could affect humans WASHINGTON: As a round-trip mission to Mars could last three years, NASA is calling for more research to understand how long-term experiences in space could affect the human body.
Typical missions to the International Space Station (ISS) last just six months. "To draw any conclusions about the cumulative effects of exposure to space, we need to observe more astronauts spending larger amounts of time in the space environment," said John Charles of the Human Research Programme at NASA's Johnson Space Center.
Combined with ongoing NASA studies, the new research could enable safer and more effective travel to destinations beyond low-Earth orbit.The US space agency hopes that such research will help it understand, prevent, diagnose, treat, mitigate and cure the potential health effects of prolonged spaceflight. "Scientists can use the information to predict physical and behavioural health trends," Charles said.
Proposals are due by January 4, 2018, and NASA expects in late summer 2018 to select 15 to 18 proposals for grants with a maximum duration of seven years.
NASA said scientists submitting proposals should consider a robust programme that could include as many as 30 astronauts -- 10 to
conduct shorter missions of up to two months, 10 as part of standard six-month missions, and 10 for one-year missions in space.
With information gained from the selected studies, NASA aims to address five hazards of human space travel - space radiation, isolation and confinement, distance from Earth, gravity fields (or lack thereof), and hostile/closed environments that pose great risks to the human mind and body in space.
"When the day comes for humans to launch on a journey to Mars, humanity will take another giant leap. The knowledge gained from this research could give NASA a running start," the US space agency said.""")

# %%
docx2 = TextBlob("""Python, from the Greek word (πύθων/πύθωνας), is a genus of
nonvenomous pythons[2] found in Africa and Asia. Currently, 7 species are
recognised.[2] A member of this genus, P. reticulatus, is among the longest
snakes known.""")

docx3 = TextBlob("""The Colt Python is a .357 Magnum caliber revolver formerly
manufactured by Colt's Manufacturing Company of Hartford, Connecticut.
It is sometimes referred to as a "Combat Magnum".[1] It was first introduced
in 1955, the same year as Smith &amp; Wesson's M29 .44 Magnum. The now discontinued
Colt Python targeted the premium revolver market segment. Some firearm
collectors and writers such as Jeff Cooper, Ian V. Hogg, Chuck Hawks, Leroy
Thompson, Renee Smeets and Martin Dougherty have described the Python as the
finest production revolver ever made.""")

# %%
docx1.tags
# Out:
# [('NASA', 'NNP'),
#  ('to', 'TO'),
#  ('explore', 'VB'),
#  ('how', 'WRB'),
#  ('3-year', 'JJ'),
#  ('Mars', 'NNP'),
#  ('mission', 'NN'),
#  ('could', 'MD'),
#  ('affect', 'VB'),
#  ('humans', 'NNS'),
#  ('WASHINGTON', 'JJ'),
#  ('As', 'IN'),
#  ('a', 'DT'),
#  ('round-trip', 'JJ'),
#  ('mission', 'NN'),
#  ('to', 'TO'),
#  ('Mars', 'NNP'),
#  ('could', 'MD'),
#  ('last', 'JJ'),
#  ('three', 'CD'),
#  ('years', 'NNS'),
#  ('NASA', 'NNP'),
#  ('is', 'VBZ'),
#  ('calling', 'VBG'),
#  ('for', 'IN'),
#  ('more', 'JJR'),
#  ('research', 'NN'),
#  ('to', 'TO'),
#  ('understand', 'VB'),
#  ('how', 'WRB'),
#  ('long-term', 'JJ'),
#  ('experiences', 'NNS'),
#  ('in', 'IN'),
#  ('space', 'NN'),
#  ('could', 'MD'),
#  ('affect', 'VB'),
#  ('the', 'DT'),
#  ('human', 'JJ'),
#  ('body', 'NN'),
#  ('Typical', 'JJ'),
#  ('missions', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('International', 'NNP'),
#  ('Space', 'NNP'),
#  ('Station', 'NNP'),
#  ('ISS', 'NNP'),
#  ('last', 'JJ'),
#  ('just', 'RB'),
#  ('six', 'CD'),
#  ('months', 'NNS'),
#  ('To', 'TO'),
#  ('draw', 'VB'),
#  ('any', 'DT'),
#  ('conclusions', 'NNS'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('cumulative', 'JJ'),
#  ('effects', 'NNS'),
#  ('of', 'IN'),
#  ('exposure', 'NN'),
#  ('to', 'TO'),
#  ('space', 'NN'),
#  ('we', 'PRP'),
#  ('need', 'VBP'),
#  ('to', 'TO'),
#  ('observe', 'VB'),
#  ('more', 'JJR'),
#  ('astronauts', 'NNS'),
#  ('spending', 'NN'),
#  ('larger', 'JJR'),
#  ('amounts', 'NNS'),
#  ('of', 'IN'),
#  ('time', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('space', 'NN'),
#  ('environment', 'NN'),
#  ('said', 'VBD'),
#  ('John', 'NNP'),
#  ('Charles', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Human', 'NNP'),
#  ('Research', 'NNP'),
#  ('Programme', 'NNP'),
#  ('at', 'IN'),
#  ('NASA', 'NNP'),
#  ("'s", 'POS'),
#  ('Johnson', 'NNP'),
#  ('Space', 'NNP'),
#  ('Center', 'NNP'),
#  ('Combined', 'VBN'),
#  ('with', 'IN'),
#  ('ongoing', 'VBG'),
#  ('NASA', 'NNP'),
#  ('studies', 'NNS'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('research', 'NN'),
#  ('could', 'MD'),
#  ('enable', 'VB'),
#  ('safer', 'JJR'),
#  ('and', 'CC'),
#  ('more', 'RBR'),
#  ('effective', 'JJ'),
#  ('travel', 'NN'),
#  ('to', 'TO'),
#  ('destinations', 'NNS'),
#  ('beyond', 'IN'),
#  ('low-Earth', 'JJ'),
#  ('orbit.The', 'JJ'),
#  ('US', 'NNP'),
#  ('space', 'NN'),
#  ('agency', 'NN'),
#  ('hopes', 'VBZ'),
#  ('that', 'IN'),
#  ('such', 'JJ'),
#  ('research', 'NN'),
#  ('will', 'MD'),
#  ('help', 'VB'),
#  ('it', 'PRP'),
#  ('understand', 'VB'),
#  ('prevent', 'NN'),
#  ('diagnose', 'VB'),
#  ('treat', 'NN'),
#  ('mitigate', 'NN'),
#  ('and', 'CC'),
#  ('cure', 'VB'),
#  ('the', 'DT'),
#  ('potential', 'JJ'),
#  ('health', 'NN'),
#  ('effects', 'NNS'),
#  ('of', 'IN'),
#  ('prolonged', 'JJ'),
#  ('spaceflight', 'NN'),
#  ('Scientists', 'NNS'),
#  ('can', 'MD'),
#  ('use', 'VB'),
#  ('the', 'DT'),
#  ('information', 'NN'),
#  ('to', 'TO'),
#  ('predict', 'VB'),
#  ('physical', 'JJ'),
#  ('and', 'CC'),
#  ('behavioural', 'JJ'),
#  ('health', 'NN'),
#  ('trends', 'NNS'),
#  ('Charles', 'NNP'),
#  ('said', 'VBD'),
#  ('Proposals', 'NNS'),
#  ('are', 'VBP'),
#  ('due', 'JJ'),
#  ('by', 'IN'),
#  ('January', 'NNP'),
#  ('4', 'CD'),
#  ('2018', 'CD'),
#  ('and', 'CC'),
#  ('NASA', 'NNP'),
#  ('expects', 'VBZ'),
#  ('in', 'IN'),
#  ('late', 'JJ'),
#  ('summer', 'NN'),
#  ('2018', 'CD'),
#  ('to', 'TO'),
#  ('select', 'VB'),
#  ('15', 'CD'),
#  ('to', 'TO'),
#  ('18', 'CD'),
#  ('proposals', 'NNS'),
#  ('for', 'IN'),
#  ('grants', 'NNS'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('maximum', 'JJ'),
#  ('duration', 'NN'),
#  ('of', 'IN'),
#  ('seven', 'CD'),
#  ('years', 'NNS'),
#  ('NASA', 'NNP'),
#  ('said', 'VBD'),
#  ('scientists', 'NNS'),
#  ('submitting', 'VBG'),
#  ('proposals', 'NNS'),
#  ('should', 'MD'),
#  ('consider', 'VB'),
#  ('a', 'DT'),
#  ('robust', 'JJ'),
#  ('programme', 'NN'),
#  ('that', 'WDT'),
#  ('could', 'MD'),
#  ('include', 'VB'),
#  ('as', 'RB'),
#  ('many', 'JJ'),
#  ('as', 'IN'),
#  ('30', 'CD'),
#  ('astronauts', 'NNS'),
#  ('10', 'CD'),
#  ('to', 'TO'),
#  ('conduct', 'VB'),
#  ('shorter', 'JJR'),
#  ('missions', 'NNS'),
#  ('of', 'IN'),
#  ('up', 'IN'),
#  ('to', 'TO'),
#  ('two', 'CD'),
#  ('months', 'NNS'),
#  ('10', 'CD'),
#  ('as', 'IN'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('standard', 'JJ'),
#  ('six-month', 'JJ'),
#  ('missions', 'NNS'),
#  ('and', 'CC'),
#  ('10', 'CD'),
#  ('for', 'IN'),
#  ('one-year', 'JJ'),
#  ('missions', 'NNS'),
#  ('in', 'IN'),
#  ('space', 'NN'),
#  ('With', 'IN'),
#  ('information', 'NN'),
#  ('gained', 'VBN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('selected', 'VBN'),
#  ('studies', 'NNS'),
#  ('NASA', 'NNP'),
#  ('aims', 'VBZ'),
#  ('to', 'TO'),
#  ('address', 'VB'),
#  ('five', 'CD'),
#  ('hazards', 'NNS'),
#  ('of', 'IN'),
#  ('human', 'JJ'),
#  ('space', 'NN'),
#  ('travel', 'NN'),
#  ('space', 'NN'),
#  ('radiation', 'NN'),
#  ('isolation', 'NN'),
#  ('and', 'CC'),
#  ('confinement', 'NN'),
#  ('distance', 'NN'),
#  ('from', 'IN'),
#  ('Earth', 'NNP'),
#  ('gravity', 'NN'),
#  ('fields', 'NNS'),
#  ('or', 'CC'),
#  ('lack', 'VB'),
#  ('thereof', 'NN'),
#  ('and', 'CC'),
#  ('hostile/closed', 'VBD'),
#  ('environments', 'NNS'),
#  ('that', 'IN'),
#  ('pose', 'VBP'),
#  ('great', 'JJ'),
#  ('risks', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('human', 'JJ'),
#  ('mind', 'NN'),
#  ('and', 'CC'),
#  ('body', 'NN'),
#  ('in', 'IN'),
#  ('space', 'NN'),
#  ('When', 'WRB'),
#  ('the', 'DT'),
#  ('day', 'NN'),
#  ('comes', 'VBZ'),
#  ('for', 'IN'),
#  ('humans', 'NNS'),
#  ('to', 'TO'),
#  ('launch', 'VB'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('journey', 'NN'),
#  ('to', 'TO'),
#  ('Mars', 'NNP'),
#  ('humanity', 'NN'),
#  ('will', 'MD'),
#  ('take', 'VB'),
#  ('another', 'DT'),
#  ('giant', 'JJ'),
#  ('leap', 'NN'),
#  ('The', 'DT'),
#  ('knowledge', 'NN'),
#  ('gained', 'VBN'),
#  ('from', 'IN'),
#  ('this', 'DT'),
#  ('research', 'NN'),
#  ('could', 'MD'),
#  ('give', 'VB'),
#  ('NASA', 'NNP'),
#  ('a', 'DT'),
#  ('running', 'JJ'),
#  ('start', 'NN'),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('space', 'NN'),
#  ('agency', 'NN'),
#  ('said', 'VBD')]

# %%
docx1.noun_phrases
# Out:
# WordList(['nasa', 'mars', 'washington', 'round-trip mission', 'mars', 'nasa', 'long-term experiences', 'human body', 'typical missions', 'international space station', 'iss', 'cumulative effects', 'space environment', 'john charles', 'human research', 'programme', 'nasa', 'johnson', 'space center', 'combined', 'nasa', 'new research', 'enable safer', 'effective travel', 'low-earth orbit.the us space agency', 'such research', 'potential health', 'scientists', 'behavioural health trends', 'charles', 'proposals', 'january', 'nasa', 'late summer', 'maximum duration', 'nasa', 'robust programme', 'conduct shorter missions', 'standard six-month missions', 'one-year missions', 'nasa', 'human space travel', 'space radiation', 'earth', 'gravity fields', 'lack thereof', 'great risks', 'human mind', 'mars', 'giant leap', 'nasa', 'us space agency'])

# %%
docx1.words
# Out:
# WordList(['NASA', 'to', 'explore', 'how', '3-year', 'Mars', 'mission', 'could', 'affect', 'humans', 'WASHINGTON', 'As', 'a', 'round-trip', 'mission', 'to', 'Mars', 'could', 'last', 'three', 'years', 'NASA', 'is', 'calling', 'for', 'more', 'research', 'to', 'understand', 'how', 'long-term', 'experiences', 'in', 'space', 'could', 'affect', 'the', 'human', 'body', 'Typical', 'missions', 'to', 'the', 'International', 'Space', 'Station', 'ISS', 'last', 'just', 'six', 'months', 'To', 'draw', 'any', 'conclusions', 'about', 'the', 'cumulative', 'effects', 'of', 'exposure', 'to', 'space', 'we', 'need', 'to', 'observe', 'more', 'astronauts', 'spending', 'larger', 'amounts', 'of', 'time', 'in', 'the', 'space', 'environment', 'said', 'John', 'Charles', 'of', 'the', 'Human', 'Research', 'Programme', 'at', 'NASA', "'s", 'Johnson', 'Space', 'Center', 'Combined', 'with', 'ongoing', 'NASA', 'studies', 'the', 'new', 'research', 'could', 'enable', 'safer', 'and', 'more', 'effective', 'travel', 'to', 'destinations', 'beyond', 'low-Earth', 'orbit.The', 'US', 'space', 'agency', 'hopes', 'that', 'such', 'research', 'will', 'help', 'it', 'understand', 'prevent', 'diagnose', 'treat', 'mitigate', 'and', 'cure', 'the', 'potential', 'health', 'effects', 'of', 'prolonged', 'spaceflight', 'Scientists', 'can', 'use', 'the', 'information', 'to', 'predict', 'physical', 'and', 'behavioural', 'health', 'trends', 'Charles', 'said', 'Proposals', 'are', 'due', 'by', 'January', '4', '2018', 'and', 'NASA', 'expects', 'in', 'late', 'summer', '2018', 'to', 'select', '15', 'to', '18', 'proposals', 'for', 'grants', 'with', 'a', 'maximum', 'duration', 'of', 'seven', 'years', 'NASA', 'said', 'scientists', 'submitting', 'proposals', 'should', 'consider', 'a', 'robust', 'programme', 'that', 'could', 'include', 'as', 'many', 'as', '30', 'astronauts', '10', 'to', 'conduct', 'shorter', 'missions', 'of', 'up', 'to', 'two', 'months', '10', 'as', 'part', 'of', 'standard', 'six-month', 'missions', 'and', '10', 'for', 'one-year', 'missions', 'in', 'space', 'With', 'information', 'gained', 'from', 'the', 'selected', 'studies', 'NASA', 'aims', 'to', 'address', 'five', 'hazards', 'of', 'human', 'space', 'travel', 'space', 'radiation', 'isolation', 'and', 'confinement', 'distance', 'from', 'Earth', 'gravity', 'fields', 'or', 'lack', 'thereof', 'and', 'hostile/closed', 'environments', 'that', 'pose', 'great', 'risks', 'to', 'the', 'human', 'mind', 'and', 'body', 'in', 'space', 'When', 'the', 'day', 'comes', 'for', 'humans', 'to', 'launch', 'on', 'a', 'journey', 'to', 'Mars', 'humanity', 'will', 'take', 'another', 'giant', 'leap', 'The', 'knowledge', 'gained', 'from', 'this', 'research', 'could', 'give', 'NASA', 'a', 'running', 'start', 'the', 'US', 'space', 'agency', 'said'])

# %%
def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

#returns the number of documents containing word
def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

#computes "inverse document frequency" which measures how common a word is among all documents in bloblist.
def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))
    #ratio of the total number of documents to the number of documents containing word

#computes tf-idf
def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)

# %%
bloblist = [docx1,docx2,docx3]
for i, blob in enumerate(bloblist):  #loops over bloblist with automatic counter i
    print("Top words in document {}".format(i + 1))
    scores = {word: tfidf(word, blob, bloblist) for word in blob.words} #find tfidf of each word with score and stores in dict scores
    sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True) #returns the list of key-value pairs in the dictionary, sorted by value from highest to lowest
    for word, score in sorted_words:
        print("\tWord: {}, TF-IDF: {}".format(word, round(score, 5)))
# Out:
# Top words in document 1
# 	Word: To, TF-IDF: 0.02282
# 	Word: space, TF-IDF: 0.01477
# 	Word: Space, TF-IDF: 0.01477
# 	Word: NASA, TF-IDF: 0.01074
# 	Word: could, TF-IDF: 0.00806
# 	Word: research, TF-IDF: 0.00671
# 	Word: Research, TF-IDF: 0.00671
# 	Word: As, TF-IDF: 0.00537
# 	Word: for, TF-IDF: 0.00537
# 	Word: human, TF-IDF: 0.00537
# 	Word: missions, TF-IDF: 0.00537
# 	Word: said, TF-IDF: 0.00537
# 	Word: Human, TF-IDF: 0.00537
# 	Word: Mars, TF-IDF: 0.00403
# 	Word: more, TF-IDF: 0.00403
# 	Word: with, TF-IDF: 0.00403
# 	Word: that, TF-IDF: 0.00403
# 	Word: Proposals, TF-IDF: 0.00403
# 	Word: proposals, TF-IDF: 0.00403
# 	Word: 10, TF-IDF: 0.00403
# 	Word: With, TF-IDF: 0.00403
# 	Word: how, TF-IDF: 0.00269
# 	Word: mission, TF-IDF: 0.00269
# 	Word: affect, TF-IDF: 0.00269
# 	Word: humans, TF-IDF: 0.00269
# 	Word: last, TF-IDF: 0.00269
# 	Word: years, TF-IDF: 0.00269
# 	Word: understand, TF-IDF: 0.00269
# 	Word: body, TF-IDF: 0.00269
# 	Word: months, TF-IDF: 0.00269
# 	Word: effects, TF-IDF: 0.00269
# 	Word: astronauts, TF-IDF: 0.00269
# 	Word: Charles, TF-IDF: 0.00269
# 	Word: Programme, TF-IDF: 0.00269
# 	Word: studies, TF-IDF: 0.00269
# 	Word: travel, TF-IDF: 0.00269
# 	Word: US, TF-IDF: 0.00269
# 	Word: agency, TF-IDF: 0.00269
# 	Word: will, TF-IDF: 0.00269
# 	Word: health, TF-IDF: 0.00269
# 	Word: Scientists, TF-IDF: 0.00269
# 	Word: information, TF-IDF: 0.00269
# 	Word: 2018, TF-IDF: 0.00269
# 	Word: scientists, TF-IDF: 0.00269
# 	Word: programme, TF-IDF: 0.00269
# 	Word: gained, TF-IDF: 0.00269
# 	Word: explore, TF-IDF: 0.00134
# 	Word: 3-year, TF-IDF: 0.00134
# 	Word: WASHINGTON, TF-IDF: 0.00134
# 	Word: round-trip, TF-IDF: 0.00134
# 	Word: three, TF-IDF: 0.00134
# 	Word: calling, TF-IDF: 0.00134
# 	Word: long-term, TF-IDF: 0.00134
# 	Word: experiences, TF-IDF: 0.00134
# 	Word: Typical, TF-IDF: 0.00134
# 	Word: International, TF-IDF: 0.00134
# 	Word: Station, TF-IDF: 0.00134
# 	Word: ISS, TF-IDF: 0.00134
# 	Word: just, TF-IDF: 0.00134
# 	Word: six, TF-IDF: 0.00134
# 	Word: draw, TF-IDF: 0.00134
# 	Word: any, TF-IDF: 0.00134
# 	Word: conclusions, TF-IDF: 0.00134
# 	Word: about, TF-IDF: 0.00134
# 	Word: cumulative, TF-IDF: 0.00134
# 	Word: exposure, TF-IDF: 0.00134
# 	Word: we, TF-IDF: 0.00134
# 	Word: need, TF-IDF: 0.00134
# 	Word: observe, TF-IDF: 0.00134
# 	Word: spending, TF-IDF: 0.00134
# 	Word: larger, TF-IDF: 0.00134
# 	Word: amounts, TF-IDF: 0.00134
# 	Word: time, TF-IDF: 0.00134
# 	Word: environment, TF-IDF: 0.00134
# 	Word: John, TF-IDF: 0.00134
# 	Word: at, TF-IDF: 0.00134
# 	Word: Johnson, TF-IDF: 0.00134
# 	Word: Center, TF-IDF: 0.00134
# 	Word: Combined, TF-IDF: 0.00134
# 	Word: ongoing, TF-IDF: 0.00134
# 	Word: new, TF-IDF: 0.00134
# 	Word: enable, TF-IDF: 0.00134
# 	Word: safer, TF-IDF: 0.00134
# 	Word: effective, TF-IDF: 0.00134
# 	Word: destinations, TF-IDF: 0.00134
# 	Word: beyond, TF-IDF: 0.00134
# 	Word: low-Earth, TF-IDF: 0.00134
# 	Word: orbit.The, TF-IDF: 0.00134
# 	Word: hopes, TF-IDF: 0.00134
# 	Word: help, TF-IDF: 0.00134
# 	Word: it, TF-IDF: 0.00134
# 	Word: prevent, TF-IDF: 0.00134
# 	Word: diagnose, TF-IDF: 0.00134
# 	Word: treat, TF-IDF: 0.00134
# 	Word: mitigate, TF-IDF: 0.00134
# 	Word: cure, TF-IDF: 0.00134
# 	Word: potential, TF-IDF: 0.00134
# 	Word: prolonged, TF-IDF: 0.00134
# 	Word: spaceflight, TF-IDF: 0.00134
# 	Word: can, TF-IDF: 0.00134
# 	Word: use, TF-IDF: 0.00134
# 	Word: predict, TF-IDF: 0.00134
# 	Word: physical, TF-IDF: 0.00134
# 	Word: behavioural, TF-IDF: 0.00134
# 	Word: trends, TF-IDF: 0.00134
# 	Word: due, TF-IDF: 0.00134
# 	Word: January, TF-IDF: 0.00134
# 	Word: 4, TF-IDF: 0.00134
# 	Word: expects, TF-IDF: 0.00134
# 	Word: late, TF-IDF: 0.00134
# 	Word: summer, TF-IDF: 0.00134
# 	Word: select, TF-IDF: 0.00134
# 	Word: 15, TF-IDF: 0.00134
# 	Word: 18, TF-IDF: 0.00134
# 	Word: grants, TF-IDF: 0.00134
# 	Word: maximum, TF-IDF: 0.00134
# 	Word: duration, TF-IDF: 0.00134
# 	Word: seven, TF-IDF: 0.00134
# 	Word: submitting, TF-IDF: 0.00134
# 	Word: should, TF-IDF: 0.00134
# 	Word: consider, TF-IDF: 0.00134
# 	Word: robust, TF-IDF: 0.00134
# 	Word: include, TF-IDF: 0.00134
# 	Word: many, TF-IDF: 0.00134
# 	Word: 30, TF-IDF: 0.00134
# 	Word: conduct, TF-IDF: 0.00134
# 	Word: shorter, TF-IDF: 0.00134
# 	Word: up, TF-IDF: 0.00134
# 	Word: two, TF-IDF: 0.00134
# 	Word: part, TF-IDF: 0.00134
# 	Word: standard, TF-IDF: 0.00134
# 	Word: six-month, TF-IDF: 0.00134
# 	Word: one-year, TF-IDF: 0.00134
# 	Word: selected, TF-IDF: 0.00134
# 	Word: aims, TF-IDF: 0.00134
# 	Word: address, TF-IDF: 0.00134
# 	Word: five, TF-IDF: 0.00134
# 	Word: hazards, TF-IDF: 0.00134
# 	Word: radiation, TF-IDF: 0.00134
# 	Word: isolation, TF-IDF: 0.00134
# 	Word: confinement, TF-IDF: 0.00134
# 	Word: distance, TF-IDF: 0.00134
# 	Word: Earth, TF-IDF: 0.00134
# 	Word: gravity, TF-IDF: 0.00134
# 	Word: fields, TF-IDF: 0.00134
# 	Word: or, TF-IDF: 0.00134
# 	Word: lack, TF-IDF: 0.00134
# 	Word: thereof, TF-IDF: 0.00134
# 	Word: hostile/closed, TF-IDF: 0.00134
# 	Word: environments, TF-IDF: 0.00134
# 	Word: pose, TF-IDF: 0.00134
# 	Word: great, TF-IDF: 0.00134
# 	Word: risks, TF-IDF: 0.00134
# 	Word: mind, TF-IDF: 0.00134
# 	Word: When, TF-IDF: 0.00134
# 	Word: day, TF-IDF: 0.00134
# 	Word: comes, TF-IDF: 0.00134
# 	Word: launch, TF-IDF: 0.00134
# 	Word: on, TF-IDF: 0.00134
# 	Word: journey, TF-IDF: 0.00134
# 	Word: humanity, TF-IDF: 0.00134
# 	Word: take, TF-IDF: 0.00134
# 	Word: another, TF-IDF: 0.00134
# 	Word: giant, TF-IDF: 0.00134
# 	Word: leap, TF-IDF: 0.00134
# 	Word: knowledge, TF-IDF: 0.00134
# 	Word: give, TF-IDF: 0.00134
# 	Word: running, TF-IDF: 0.00134
# 	Word: start, TF-IDF: 0.00134
# 	Word: to, TF-IDF: 0.0
# 	Word: 's, TF-IDF: 0.0
# 	Word: such, TF-IDF: 0.0
# 	Word: are, TF-IDF: 0.0
# 	Word: by, TF-IDF: 0.0
# 	Word: as, TF-IDF: 0.0
# 	Word: from, TF-IDF: 0.0
# 	Word: The, TF-IDF: 0.0
# 	Word: this, TF-IDF: 0.0
# 	Word: is, TF-IDF: -0.00095
# 	Word: a, TF-IDF: -0.00476
# 	Word: in, TF-IDF: -0.00476
# 	Word: of, TF-IDF: -0.00762
# 	Word: and, TF-IDF: -0.00762
# 	Word: the, TF-IDF: -0.01238
# Top words in document 2
# 	Word: genus, TF-IDF: 0.02192
# 	Word: 2, TF-IDF: 0.02192
# 	Word: A, TF-IDF: 0.02192
# 	Word: Greek, TF-IDF: 0.01096
# 	Word: word, TF-IDF: 0.01096
# 	Word: πύθων/πύθωνας, TF-IDF: 0.01096
# 	Word: nonvenomous, TF-IDF: 0.01096
# 	Word: pythons, TF-IDF: 0.01096
# 	Word: found, TF-IDF: 0.01096
# 	Word: Africa, TF-IDF: 0.01096
# 	Word: Asia, TF-IDF: 0.01096
# 	Word: Currently, TF-IDF: 0.01096
# 	Word: 7, TF-IDF: 0.01096
# 	Word: species, TF-IDF: 0.01096
# 	Word: recognised, TF-IDF: 0.01096
# 	Word: member, TF-IDF: 0.01096
# 	Word: P, TF-IDF: 0.01096
# 	Word: reticulatus, TF-IDF: 0.01096
# 	Word: among, TF-IDF: 0.01096
# 	Word: longest, TF-IDF: 0.01096
# 	Word: snakes, TF-IDF: 0.01096
# 	Word: known, TF-IDF: 0.01096
# 	Word: Python, TF-IDF: 0.0
# 	Word: from, TF-IDF: 0.0
# 	Word: are, TF-IDF: 0.0
# 	Word: this, TF-IDF: 0.0
# 	Word: in, TF-IDF: -0.00778
# 	Word: and, TF-IDF: -0.00778
# 	Word: the, TF-IDF: -0.01555
# 	Word: is, TF-IDF: -0.01555
# 	Word: a, TF-IDF: -0.01555
# 	Word: of, TF-IDF: -0.01555
# Top words in document 3
# 	Word: Colt, TF-IDF: 0.01367
# 	Word: Magnum, TF-IDF: 0.01367
# 	Word: revolver, TF-IDF: 0.01367
# 	Word: It, TF-IDF: 0.00911
# 	Word: 357, TF-IDF: 0.00456
# 	Word: caliber, TF-IDF: 0.00456
# 	Word: formerly, TF-IDF: 0.00456
# 	Word: manufactured, TF-IDF: 0.00456
# 	Word: Manufacturing, TF-IDF: 0.00456
# 	Word: Company, TF-IDF: 0.00456
# 	Word: Hartford, TF-IDF: 0.00456
# 	Word: Connecticut, TF-IDF: 0.00456
# 	Word: sometimes, TF-IDF: 0.00456
# 	Word: referred, TF-IDF: 0.00456
# 	Word: Combat, TF-IDF: 0.00456
# 	Word: 1, TF-IDF: 0.00456
# 	Word: was, TF-IDF: 0.00456
# 	Word: first, TF-IDF: 0.00456
# 	Word: introduced, TF-IDF: 0.00456
# 	Word: 1955, TF-IDF: 0.00456
# 	Word: same, TF-IDF: 0.00456
# 	Word: year, TF-IDF: 0.00456
# 	Word: Smith, TF-IDF: 0.00456
# 	Word: amp, TF-IDF: 0.00456
# 	Word: Wesson, TF-IDF: 0.00456
# 	Word: M29, TF-IDF: 0.00456
# 	Word: 44, TF-IDF: 0.00456
# 	Word: now, TF-IDF: 0.00456
# 	Word: discontinued, TF-IDF: 0.00456
# 	Word: targeted, TF-IDF: 0.00456
# 	Word: premium, TF-IDF: 0.00456
# 	Word: market, TF-IDF: 0.00456
# 	Word: segment, TF-IDF: 0.00456
# 	Word: Some, TF-IDF: 0.00456
# 	Word: firearm, TF-IDF: 0.00456
# 	Word: collectors, TF-IDF: 0.00456
# 	Word: writers, TF-IDF: 0.00456
# 	Word: Jeff, TF-IDF: 0.00456
# 	Word: Cooper, TF-IDF: 0.00456
# 	Word: Ian, TF-IDF: 0.00456
# 	Word: V, TF-IDF: 0.00456
# 	Word: Hogg, TF-IDF: 0.00456
# 	Word: Chuck, TF-IDF: 0.00456
# 	Word: Hawks, TF-IDF: 0.00456
# 	Word: Leroy, TF-IDF: 0.00456
# 	Word: Thompson, TF-IDF: 0.00456
# 	Word: Renee, TF-IDF: 0.00456
# 	Word: Smeets, TF-IDF: 0.00456
# 	Word: Martin, TF-IDF: 0.00456
# 	Word: Dougherty, TF-IDF: 0.00456
# 	Word: have, TF-IDF: 0.00456
# 	Word: described, TF-IDF: 0.00456
# 	Word: finest, TF-IDF: 0.00456
# 	Word: production, TF-IDF: 0.00456
# 	Word: ever, TF-IDF: 0.00456
# 	Word: made, TF-IDF: 0.00456
# 	Word: The, TF-IDF: 0.0
# 	Word: Python, TF-IDF: 0.0
# 	Word: by, TF-IDF: 0.0
# 	Word: 's, TF-IDF: 0.0
# 	Word: to, TF-IDF: 0.0
# 	Word: as, TF-IDF: 0.0
# 	Word: such, TF-IDF: 0.0
# 	Word: of, TF-IDF: -0.00323
# 	Word: in, TF-IDF: -0.00323
# 	Word: is, TF-IDF: -0.00646
# 	Word: a, TF-IDF: -0.00646
# 	Word: and, TF-IDF: -0.00646
# 	Word: the, TF-IDF: -0.01939

# %%
print(scores)
# Out:
# {'The': 0.0, 'Colt': 0.013667363194657226, 'Python': 0.0, 'is': -0.006464765673073728, 'a': -0.006464765673073728, '357': 0.0045557877315524084, 'Magnum': 0.013667363194657226, 'caliber': 0.0045557877315524084, 'revolver': 0.013667363194657226, 'formerly': 0.0045557877315524084, 'manufactured': 0.0045557877315524084, 'by': 0.0, "'s": 0.0, 'Manufacturing': 0.0045557877315524084, 'Company': 0.0045557877315524084, 'of': -0.003232382836536864, 'Hartford': 0.0045557877315524084, 'Connecticut': 0.0045557877315524084, 'It': 0.009111575463104817, 'sometimes': 0.0045557877315524084, 'referred': 0.0045557877315524084, 'to': 0.0, 'as': 0.0, 'Combat': 0.0045557877315524084, '1': 0.0045557877315524084, 'was': 0.0045557877315524084, 'first': 0.0045557877315524084, 'introduced': 0.0045557877315524084, 'in': -0.003232382836536864, '1955': 0.0045557877315524084, 'the': -0.019394297019221185, 'same': 0.0045557877315524084, 'year': 0.0045557877315524084, 'Smith': 0.0045557877315524084, 'amp': 0.0045557877315524084, 'Wesson': 0.0045557877315524084, 'M29': 0.0045557877315524084, '44': 0.0045557877315524084, 'now': 0.0045557877315524084, 'discontinued': 0.0045557877315524084, 'targeted': 0.0045557877315524084, 'premium': 0.0045557877315524084, 'market': 0.0045557877315524084, 'segment': 0.0045557877315524084, 'Some': 0.0045557877315524084, 'firearm': 0.0045557877315524084, 'collectors': 0.0045557877315524084, 'and': -0.006464765673073728, 'writers': 0.0045557877315524084, 'such': 0.0, 'Jeff': 0.0045557877315524084, 'Cooper': 0.0045557877315524084, 'Ian': 0.0045557877315524084, 'V': 0.0045557877315524084, 'Hogg': 0.0045557877315524084, 'Chuck': 0.0045557877315524084, 'Hawks': 0.0045557877315524084, 'Leroy': 0.0045557877315524084, 'Thompson': 0.0045557877315524084, 'Renee': 0.0045557877315524084, 'Smeets': 0.0045557877315524084, 'Martin': 0.0045557877315524084, 'Dougherty': 0.0045557877315524084, 'have': 0.0045557877315524084, 'described': 0.0045557877315524084, 'finest': 0.0045557877315524084, 'production': 0.0045557877315524084, 'ever': 0.0045557877315524084, 'made': 0.0045557877315524084}
